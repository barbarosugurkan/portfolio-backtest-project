# %%
# %load_ext sql
# %sql sqlite:///Chinook_Sqlite.sqlite
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# Question 1
#
# Pull a list of customer ids with the customer’s full name, and address, along with combining their city and country together. Be sure to make a space in between these two and make it UPPER CASE. (e.g. LOS ANGELES USA)

# %%
# %%sql
#
# SELECT CustomerID, FirstName || " " || LastName AS FullName, Address, UPPER(City) || " " || UPPER(Country) AS CityCountry
# FROM Customer
# LIMIT 10
# Out:
#  * sqlite:///Chinook_Sqlite.sqlite
# Done.
# [(1, 'Luís Gonçalves', 'Av. Brigadeiro Faria Lima, 2170', 'SãO JOSé DOS CAMPOS BRAZIL'),
#  (2, 'Leonie Köhler', 'Theodor-Heuss-Straße 34', 'STUTTGART GERMANY'),
#  (3, 'François Tremblay', '1498 rue Bélanger', 'MONTRéAL CANADA'),
#  (4, 'Bjørn Hansen', 'Ullevålsveien 14', 'OSLO NORWAY'),
#  (5, 'František Wichterlová', 'Klanova 9/506', 'PRAGUE CZECH REPUBLIC'),
#  (6, 'Helena Holý', 'Rilská 3174/6', 'PRAGUE CZECH REPUBLIC'),
#  (7, 'Astrid Gruber', 'Rotenturmstraße 4, 1010 Innere Stadt', 'VIENNE AUSTRIA'),
#  (8, 'Daan Peeters', 'Grétrystraat 63', 'BRUSSELS BELGIUM'),
#  (9, 'Kara Nielsen', 'Sønder Boulevard 51', 'COPENHAGEN DENMARK'),
#  (10, 'Eduardo Martins', 'Rua Dr. Falcão Filho, 155', 'SãO PAULO BRAZIL')]

# %% [markdown]
# Question 2
#
# Create a new employee user id by combining the first 4 letters of the employee’s first name with the first 2 letters of the employee’s last name. Make the new field lower case and pull each individual step to show your work.

# %%
# %%sql
#
# SELECT LOWER(SUBSTR(FirstName,1,4)) || LOWER(SUBSTR(LastName,1,2)) AS new_employee_id
# FROM Employee
# Out:
#  * sqlite:///Chinook_Sqlite.sqlite
# Done.
# [('andrad', 'Andrew'),
#  ('nanced', 'Nancy'),
#  ('janepe', 'Jane'),
#  ('margpa', 'Margaret'),
#  ('stevjo', 'Steve'),
#  ('michmi', 'Michael'),
#  ('robeki', 'Robert'),
#  ('laurca', 'Laura')]

# %% [markdown]
# Question 3
#
# Show a list of employees who have worked for the company for 15 or more years using the current date function. Sort by lastname ascending.

# %%
# %%sql
#
# SELECT FirstName || " " || LastName AS FullName, STRFTIME(DATE("now")- HireDate) AS Experience
# FROM Employee
# WHERE Experience >= 15
# ORDER BY LastName
# Out:
#  * sqlite:///Chinook_Sqlite.sqlite
# Done.
# [('Andrew Adams', '23'),
#  ('Laura Callahan', '21'),
#  ('Nancy Edwards', '23'),
#  ('Steve Johnson', '22'),
#  ('Robert King', '21'),
#  ('Michael Mitchell', '22'),
#  ('Margaret Park', '22'),
#  ('Jane Peacock', '23')]

# %% [markdown]
# Question 4
#
# Profiling the Customers table, answer the following question.
# Are there any columns with null values? Indicate any below. Select all that apply.

# %%
# %%sql
#
# SELECT FirstName,Phone,Company,Address,Fax,PostalCode
# FROM Customer
# WHERE PostalCode IS NULL
# Out:
#  * sqlite:///Chinook_Sqlite.sqlite
# Done.
# [('João', '+351 (213) 466-111', None, 'Rua da Assunção 53', None, None),
#  ('Madalena', '+351 (225) 022-448', None, 'Rua dos Campeões Europeus de Viena, 4350', None, None),
#  ('Hugh', '+353 01 6792424', None, '3 Chatham Street', None, None),
#  ('Luis', '+56 (0)2 635 4444', None, 'Calle Lira, 198', None, None)]

# %% [markdown]
# Question 5
#
# Find the cities with the most customers and rank in descending order.

# %%
# %%sql
#
# SELECT City, COUNT(*)
# FROM Customer
# GROUP BY City
# ORDER BY COUNT(*) DESC
# LIMIT 10
# Out:
#  * sqlite:///Chinook_Sqlite.sqlite
# Done.
# [('São Paulo', 2),
#  ('Prague', 2),
#  ('Paris', 2),
#  ('Mountain View', 2),
#  ('London', 2),
#  ('Berlin', 2),
#  ('Yellowknife', 1),
#  ('Winnipeg', 1),
#  ('Warsaw', 1),
#  ('Vienne', 1)]

# %% [markdown]
# Question 6
#
# Create a new customer invoice id by combining a customer’s invoice id with their first and last name while ordering your query in the following order: firstname, lastname, and invoiceID.

# %%
# %%sql
#
# SELECT c.FirstName || c.LastName || i.InvoiceID AS NewInvoiceID, c.FirstName, c.LastName
# FROM Customer c
# INNER JOIN Invoice i ON i.CustomerID = c.CustomerID
# ORDER BY c.FirstName, c.LastName, i.InvoiceID
# Out:
#  * sqlite:///Chinook_Sqlite.sqlite
# Done.
# [('AaronMitchell50', 'Aaron', 'Mitchell'),
#  ('AaronMitchell61', 'Aaron', 'Mitchell'),
#  ('AaronMitchell116', 'Aaron', 'Mitchell'),
#  ('AaronMitchell245', 'Aaron', 'Mitchell'),
#  ('AaronMitchell268', 'Aaron', 'Mitchell'),
#  ('AaronMitchell290', 'Aaron', 'Mitchell'),
#  ('AaronMitchell342', 'Aaron', 'Mitchell'),
#  ('AlexandreRocha57', 'Alexandre', 'Rocha'),
#  ('AlexandreRocha68', 'Alexandre', 'Rocha'),
#  ('AlexandreRocha123', 'Alexandre', 'Rocha'),
#  ('AlexandreRocha252', 'Alexandre', 'Rocha'),
#  ('AlexandreRocha275', 'Alexandre', 'Rocha'),
#  ('AlexandreRocha297', 'Alexandre', 'Rocha'),
#  ('AlexandreRocha349', 'Alexandre', 'Rocha'),
#  ('AstridGruber78', 'Astrid', 'Gruber'),
#  ('AstridGruber89', 'Astrid', 'Gruber'),
#  ('AstridGruber144', 'Astrid', 'Gruber'),
#  ('AstridGruber273', 'Astrid', 'Gruber'),
#  ('AstridGruber296', 'Astrid', 'Gruber'),
#  ('AstridGruber318', 'Astrid', 'Gruber'),
#  ('AstridGruber370', 'Astrid', 'Gruber'),
#  ('BjørnHansen2', 'Bjørn', 'Hansen'),
#  ('BjørnHansen24', 'Bjørn', 'Hansen'),
#  ('BjørnHansen76', 'Bjørn', 'Hansen'),
#  ('BjørnHansen197', 'Bjørn', 'Hansen'),
#  ('BjørnHansen208', 'Bjørn', 'Hansen'),
#  ('BjørnHansen263', 'Bjørn', 'Hansen'),
#  ('BjørnHansen392', 'Bjørn', 'Hansen'),
#  ('CamilleBernard105', 'Camille', 'Bernard'),
#  ('CamilleBernard128', 'Camille', 'Bernard'),
#  ('CamilleBernard150', 'Camille', 'Bernard'),
#  ('CamilleBernard202', 'Camille', 'Bernard'),
#  ('CamilleBernard323', 'Camille', 'Bernard'),
#  ('CamilleBernard334', 'Camille', 'Bernard'),
#  ('CamilleBernard389', 'Camille', 'Bernard'),
#  ('DaanPeeters3', 'Daan', 'Peeters'),
#  ('DaanPeeters55', 'Daan', 'Peeters'),
#  ('DaanPeeters176', 'Daan', 'Peeters'),
#  ('DaanPeeters187', 'Daan', 'Peeters'),
#  ('DaanPeeters242', 'Daan', 'Peeters'),
#  ('DaanPeeters371', 'Daan', 'Peeters'),
#  ('DaanPeeters394', 'Daan', 'Peeters'),
#  ('DanMiller113', 'Dan', 'Miller'),
#  ('DanMiller124', 'Dan', 'Miller'),
#  ('DanMiller179', 'Dan', 'Miller'),
#  ('DanMiller308', 'Dan', 'Miller'),
#  ('DanMiller331', 'Dan', 'Miller'),
#  ('DanMiller353', 'Dan', 'Miller'),
#  ('DanMiller405', 'Dan', 'Miller'),
#  ('DiegoGutiérrez119', 'Diego', 'Gutiérrez'),
#  ('DiegoGutiérrez142', 'Diego', 'Gutiérrez'),
#  ('DiegoGutiérrez164', 'Diego', 'Gutiérrez'),
#  ('DiegoGutiérrez216', 'Diego', 'Gutiérrez'),
#  ('DiegoGutiérrez337', 'Diego', 'Gutiérrez'),
#  ('DiegoGutiérrez348', 'Diego', 'Gutiérrez'),
#  ('DiegoGutiérrez403', 'Diego', 'Gutiérrez'),
#  ('DominiqueLefebvre8', 'Dominique', 'Lefebvre'),
#  ('DominiqueLefebvre19', 'Dominique', 'Lefebvre'),
#  ('DominiqueLefebvre74', 'Dominique', 'Lefebvre'),
#  ('DominiqueLefebvre203', 'Dominique', 'Lefebvre'),
#  ('DominiqueLefebvre226', 'Dominique', 'Lefebvre'),
#  ('DominiqueLefebvre248', 'Dominique', 'Lefebvre'),
#  ('DominiqueLefebvre300', 'Dominique', 'Lefebvre'),
#  ('EduardoMartins25', 'Eduardo', 'Martins'),
#  ('EduardoMartins154', 'Eduardo', 'Martins'),
#  ('EduardoMartins177', 'Eduardo', 'Martins'),
#  ('EduardoMartins199', 'Eduardo', 'Martins'),
#  ('EduardoMartins251', 'Eduardo', 'Martins'),
#  ('EduardoMartins372', 'Eduardo', 'Martins'),
#  ('EduardoMartins383', 'Eduardo', 'Martins'),
#  ('EdwardFrancis49', 'Edward', 'Francis'),
#  ('EdwardFrancis72', 'Edward', 'Francis'),
#  ('EdwardFrancis94', 'Edward', 'Francis'),
#  ('EdwardFrancis146', 'Edward', 'Francis'),
#  ('EdwardFrancis267', 'Edward', 'Francis'),
#  ('EdwardFrancis278', 'Edward', 'Francis'),
#  ('EdwardFrancis333', 'Edward', 'Francis'),
#  ('EllieSullivan27', 'Ellie', 'Sullivan'),
#  ('EllieSullivan148', 'Ellie', 'Sullivan'),
#  ('EllieSullivan159', 'Ellie', 'Sullivan'),
#  ('EllieSullivan214', 'Ellie', 'Sullivan'),
#  ('EllieSullivan343', 'Ellie', 'Sullivan'),
#  ('EllieSullivan366', 'Ellie', 'Sullivan'),
#  ('EllieSullivan388', 'Ellie', 'Sullivan'),
#  ('EmmaJones11', 'Emma', 'Jones'),
#  ('EmmaJones140', 'Emma', 'Jones'),
#  ('EmmaJones163', 'Emma', 'Jones'),
#  ('EmmaJones185', 'Emma', 'Jones'),
#  ('EmmaJones237', 'Emma', 'Jones'),
#  ('EmmaJones358', 'Emma', 'Jones'),
#  ('EmmaJones369', 'Emma', 'Jones'),
#  ('EnriqueMuñoz41', 'Enrique', 'Muñoz'),
#  ('EnriqueMuñoz162', 'Enrique', 'Muñoz'),
#  ('EnriqueMuñoz173', 'Enrique', 'Muñoz'),
#  ('EnriqueMuñoz228', 'Enrique', 'Muñoz'),
#  ('EnriqueMuñoz357', 'Enrique', 'Muñoz'),
#  ('EnriqueMuñoz380', 'Enrique', 'Muñoz'),
#  ('EnriqueMuñoz402', 'Enrique', 'Muñoz'),
#  ('FernandaRamos35', 'Fernanda', 'Ramos'),
#  ('FernandaRamos58', 'Fernanda', 'Ramos'),
#  ('FernandaRamos80', 'Fernanda', 'Ramos'),
#  ('FernandaRamos132', 'Fernanda', 'Ramos'),
#  ('FernandaRamos253', 'Fernanda', 'Ramos'),
#  ('FernandaRamos264', 'Fernanda', 'Ramos'),
#  ('FernandaRamos319', 'Fernanda', 'Ramos'),
#  ('FrankHarris13', 'Frank', 'Harris'),
#  ('FrankHarris134', 'Frank', 'Harris'),
#  ('FrankHarris145', 'Frank', 'Harris'),
#  ('FrankHarris200', 'Frank', 'Harris'),
#  ('FrankHarris329', 'Frank', 'Harris'),
#  ('FrankHarris352', 'Frank', 'Harris'),
#  ('FrankHarris374', 'Frank', 'Harris'),
#  ('FrankRalston92', 'Frank', 'Ralston'),
#  ('FrankRalston103', 'Frank', 'Ralston'),
#  ('FrankRalston158', 'Frank', 'Ralston'),
#  ('FrankRalston287', 'Frank', 'Ralston'),
#  ('FrankRalston310', 'Frank', 'Ralston'),
#  ('FrankRalston332', 'Frank', 'Ralston'),
#  ('FrankRalston384', 'Frank', 'Ralston'),
#  ('FrantišekWichterlová77', 'František', 'Wichterlová'),
#  ('FrantišekWichterlová100', 'František', 'Wichterlová'),
#  ('FrantišekWichterlová122', 'František', 'Wichterlová'),
#  ('FrantišekWichterlová174', 'František', 'Wichterlová'),
#  ('FrantišekWichterlová295', 'František', 'Wichterlová'),
#  ('FrantišekWichterlová306', 'František', 'Wichterlová'),
#  ('FrantišekWichterlová361', 'František', 'Wichterlová'),
#  ('FrançoisTremblay99', 'François', 'Tremblay'),
#  ('FrançoisTremblay110', 'François', 'Tremblay'),
#  ('FrançoisTremblay165', 'François', 'Tremblay'),
#  ('FrançoisTremblay294', 'François', 'Tremblay'),
#  ('FrançoisTremblay317', 'François', 'Tremblay'),
#  ('FrançoisTremblay339', 'François', 'Tremblay'),
#  ('FrançoisTremblay391', 'François', 'Tremblay'),
#  ('FynnZimmermann6', 'Fynn', 'Zimmermann'),
#  ('FynnZimmermann127', 'Fynn', 'Zimmermann'),
#  ('FynnZimmermann138', 'Fynn', 'Zimmermann'),
#  ('FynnZimmermann193', 'Fynn', 'Zimmermann'),
#  ('FynnZimmermann322', 'Fynn', 'Zimmermann'),
#  ('FynnZimmermann345', 'Fynn', 'Zimmermann'),
#  ('FynnZimmermann367', 'Fynn', 'Zimmermann'),
#  ('HannahSchneider29', 'Hannah', 'Schneider'),
#  ('HannahSchneider40', 'Hannah', 'Schneider'),
#  ('HannahSchneider95', 'Hannah', 'Schneider'),
#  ('HannahSchneider224', 'Hannah', 'Schneider'),
#  ('HannahSchneider247', 'Hannah', 'Schneider'),
#  ('HannahSchneider269', 'Hannah', 'Schneider'),
#  ('HannahSchneider321', 'Hannah', 'Schneider'),
#  ('HeatherLeacock91', 'Heather', 'Leacock'),
#  ('HeatherLeacock114', 'Heather', 'Leacock'),
#  ('HeatherLeacock136', 'Heather', 'Leacock'),
#  ('HeatherLeacock188', 'Heather', 'Leacock'),
#  ('HeatherLeacock309', 'Heather', 'Leacock'),
#  ('HeatherLeacock320', 'Heather', 'Leacock'),
#  ('HeatherLeacock375', 'Heather', 'Leacock'),
#  ('HelenaHolý46', 'Helena', 'Holý'),
#  ('HelenaHolý175', 'Helena', 'Holý'),
#  ('HelenaHolý198', 'Helena', 'Holý'),
#  ('HelenaHolý220', 'Helena', 'Holý'),
#  ('HelenaHolý272', 'Helena', 'Holý'),
#  ('HelenaHolý393', 'Helena', 'Holý'),
#  ('HelenaHolý404', 'Helena', 'Holý'),
#  ("HughO'Reilly10", 'Hugh', "O'Reilly"),
#  ("HughO'Reilly62", 'Hugh', "O'Reilly"),
#  ("HughO'Reilly183", 'Hugh', "O'Reilly"),
#  ("HughO'Reilly194", 'Hugh', "O'Reilly"),
#  ("HughO'Reilly249", 'Hugh', "O'Reilly"),
#  ("HughO'Reilly378", 'Hugh', "O'Reilly"),
#  ("HughO'Reilly401", 'Hugh', "O'Reilly"),
#  ('IsabelleMercier84', 'Isabelle', 'Mercier'),
#  ('IsabelleMercier107', 'Isabelle', 'Mercier'),
#  ('IsabelleMercier129', 'Isabelle', 'Mercier'),
#  ('IsabelleMercier181', 'Isabelle', 'Mercier'),
#  ('IsabelleMercier302', 'Isabelle', 'Mercier'),
#  ('IsabelleMercier313', 'Isabelle', 'Mercier'),
#  ('IsabelleMercier368', 'Isabelle', 'Mercier'),
#  ('JackSmith14', 'Jack', 'Smith'),
#  ('JackSmith37', 'Jack', 'Smith'),
#  ('JackSmith59', 'Jack', 'Smith'),
#  ('JackSmith111', 'Jack', 'Smith'),
#  ('JackSmith232', 'Jack', 'Smith'),
#  ('JackSmith243', 'Jack', 'Smith'),
#  ('JackSmith298', 'Jack', 'Smith'),
#  ('JenniferPeterson36', 'Jennifer', 'Peterson'),
#  ('JenniferPeterson47', 'Jennifer', 'Peterson'),
#  ('JenniferPeterson102', 'Jennifer', 'Peterson'),
#  ('JenniferPeterson231', 'Jennifer', 'Peterson'),
#  ('JenniferPeterson254', 'Jennifer', 'Peterson'),
#  ('JenniferPeterson276', 'Jennifer', 'Peterson'),
#  ('JenniferPeterson328', 'Jennifer', 'Peterson'),
#  ('JoakimJohansson42', 'Joakim', 'Johansson'),
#  ('JoakimJohansson65', 'Joakim', 'Johansson'),
#  ('JoakimJohansson87', 'Joakim', 'Johansson'),
#  ('JoakimJohansson139', 'Joakim', 'Johansson'),
#  ('JoakimJohansson260', 'Joakim', 'Johansson'),
#  ('JoakimJohansson271', 'Joakim', 'Johansson'),
#  ('JoakimJohansson326', 'Joakim', 'Johansson'),
#  ('JohannesVan der Berg32', 'Johannes', 'Van der Berg'),
#  ('JohannesVan der Berg161', 'Johannes', 'Van der Berg'),
#  ('JohannesVan der Berg184', 'Johannes', 'Van der Berg'),
#  ('JohannesVan der Berg206', 'Johannes', 'Van der Berg'),
#  ('JohannesVan der Berg258', 'Johannes', 'Van der Berg'),
#  ('JohannesVan der Berg379', 'Johannes', 'Van der Berg'),
#  ('JohannesVan der Berg390', 'Johannes', 'Van der Berg'),
#  ('JohnGordon5', 'John', 'Gordon'),
#  ('JohnGordon60', 'John', 'Gordon'),
#  ('JohnGordon189', 'John', 'Gordon'),
#  ('JohnGordon212', 'John', 'Gordon'),
#  ('JohnGordon234', 'John', 'Gordon'),
#  ('JohnGordon286', 'John', 'Gordon'),
#  ('JohnGordon407', 'John', 'Gordon'),
#  ('JoãoFernandes28', 'João', 'Fernandes'),
#  ('JoãoFernandes51', 'João', 'Fernandes'),
#  ('JoãoFernandes73', 'João', 'Fernandes'),
#  ('JoãoFernandes125', 'João', 'Fernandes'),
#  ('JoãoFernandes246', 'João', 'Fernandes'),
#  ('JoãoFernandes257', 'João', 'Fernandes'),
#  ('JoãoFernandes312', 'João', 'Fernandes'),
#  ('JuliaBarnett71', 'Julia', 'Barnett'),
#  ('JuliaBarnett82', 'Julia', 'Barnett'),
#  ('JuliaBarnett137', 'Julia', 'Barnett'),
#  ('JuliaBarnett266', 'Julia', 'Barnett'),
#  ('JuliaBarnett289', 'Julia', 'Barnett'),
#  ('JuliaBarnett311', 'Julia', 'Barnett'),
#  ('JuliaBarnett363', 'Julia', 'Barnett'),
#  ('KaraNielsen56', 'Kara', 'Nielsen'),
#  ('KaraNielsen79', 'Kara', 'Nielsen'),
#  ('KaraNielsen101', 'Kara', 'Nielsen'),
#  ('KaraNielsen153', 'Kara', 'Nielsen'),
#  ('KaraNielsen274', 'Kara', 'Nielsen'),
#  ('KaraNielsen285', 'Kara', 'Nielsen'),
#  ('KaraNielsen340', 'Kara', 'Nielsen'),
#  ('KathyChase16', 'Kathy', 'Chase'),
#  ('KathyChase38', 'Kathy', 'Chase'),
#  ('KathyChase90', 'Kathy', 'Chase'),
#  ('KathyChase211', 'Kathy', 'Chase'),
#  ('KathyChase222', 'Kathy', 'Chase'),
#  ('KathyChase277', 'Kathy', 'Chase'),
#  ('KathyChase406', 'Kathy', 'Chase'),
#  ('LadislavKovács85', 'Ladislav', 'Kovács'),
#  ('LadislavKovács96', 'Ladislav', 'Kovács'),
#  ('LadislavKovács151', 'Ladislav', 'Kovács'),
#  ('LadislavKovács280', 'Ladislav', 'Kovács'),
#  ('LadislavKovács303', 'Ladislav', 'Kovács'),
#  ('LadislavKovács325', 'Ladislav', 'Kovács'),
#  ('LadislavKovács377', 'Ladislav', 'Kovács'),
#  ('LeonieKöhler1', 'Leonie', 'Köhler'),
#  ('LeonieKöhler12', 'Leonie', 'Köhler'),
#  ('LeonieKöhler67', 'Leonie', 'Köhler'),
#  ('LeonieKöhler196', 'Leonie', 'Köhler'),
#  ('LeonieKöhler219', 'Leonie', 'Köhler'),
#  ('LeonieKöhler241', 'Leonie', 'Köhler'),
#  ('LeonieKöhler293', 'Leonie', 'Köhler'),
#  ('LucasMancini63', 'Lucas', 'Mancini'),
#  ('LucasMancini86', 'Lucas', 'Mancini'),
#  ('LucasMancini108', 'Lucas', 'Mancini'),
#  ('LucasMancini160', 'Lucas', 'Mancini'),
#  ('LucasMancini281', 'Lucas', 'Mancini'),
#  ('LucasMancini292', 'Lucas', 'Mancini'),
#  ('LucasMancini347', 'Lucas', 'Mancini'),
#  ('LuisRojas22', 'Luis', 'Rojas'),
#  ('LuisRojas33', 'Luis', 'Rojas'),
#  ('LuisRojas88', 'Luis', 'Rojas'),
#  ('LuisRojas217', 'Luis', 'Rojas'),
#  ('LuisRojas240', 'Luis', 'Rojas'),
#  ('LuisRojas262', 'Luis', 'Rojas'),
#  ('LuisRojas314', 'Luis', 'Rojas'),
#  ('LuísGonçalves98', 'Luís', 'Gonçalves'),
#  ('LuísGonçalves121', 'Luís', 'Gonçalves'),
#  ('LuísGonçalves143', 'Luís', 'Gonçalves'),
#  ('LuísGonçalves195', 'Luís', 'Gonçalves'),
#  ('LuísGonçalves316', 'Luís', 'Gonçalves'),
#  ('LuísGonçalves327', 'Luís', 'Gonçalves'),
#  ('LuísGonçalves382', 'Luís', 'Gonçalves'),
#  ('MadalenaSampaio126', 'Madalena', 'Sampaio'),
#  ('MadalenaSampaio149', 'Madalena', 'Sampaio'),
#  ('MadalenaSampaio171', 'Madalena', 'Sampaio'),
#  ('MadalenaSampaio223', 'Madalena', 'Sampaio'),
#  ('MadalenaSampaio344', 'Madalena', 'Sampaio'),
#  ('MadalenaSampaio355', 'Madalena', 'Sampaio'),
#  ('MadalenaSampaio410', 'Madalena', 'Sampaio'),
#  ('ManojPareek120', 'Manoj', 'Pareek'),
#  ('ManojPareek131', 'Manoj', 'Pareek'),
#  ('ManojPareek186', 'Manoj', 'Pareek'),
#  ('ManojPareek315', 'Manoj', 'Pareek'),
#  ('ManojPareek338', 'Manoj', 'Pareek'),
#  ('ManojPareek360', 'Manoj', 'Pareek'),
#  ('ManojPareek412', 'Manoj', 'Pareek'),
#  ('MarcDubois106', 'Marc', 'Dubois'),
#  ('MarcDubois117', 'Marc', 'Dubois'),
#  ('MarcDubois172', 'Marc', 'Dubois'),
#  ('MarcDubois301', 'Marc', 'Dubois'),
#  ('MarcDubois324', 'Marc', 'Dubois'),
#  ('MarcDubois346', 'Marc', 'Dubois'),
#  ('MarcDubois398', 'Marc', 'Dubois'),
#  ('MarkPhilips4', 'Mark', 'Philips'),
#  ('MarkPhilips133', 'Mark', 'Philips'),
#  ('MarkPhilips156', 'Mark', 'Philips'),
#  ('MarkPhilips178', 'Mark', 'Philips'),
#  ('MarkPhilips230', 'Mark', 'Philips'),
#  ('MarkPhilips351', 'Mark', 'Philips'),
#  ('MarkPhilips362', 'Mark', 'Philips'),
#  ('MarkTaylor21', 'Mark', 'Taylor'),
#  ('MarkTaylor44', 'Mark', 'Taylor'),
#  ('MarkTaylor66', 'Mark', 'Taylor'),
#  ('MarkTaylor118', 'Mark', 'Taylor'),
#  ('MarkTaylor239', 'Mark', 'Taylor'),
#  ('MarkTaylor250', 'Mark', 'Taylor'),
#  ('MarkTaylor305', 'Mark', 'Taylor'),
#  ('MarthaSilk18', 'Martha', 'Silk'),
#  ('MarthaSilk147', 'Martha', 'Silk'),
#  ('MarthaSilk170', 'Martha', 'Silk'),
#  ('MarthaSilk192', 'Martha', 'Silk'),
#  ('MarthaSilk244', 'Martha', 'Silk'),
#  ('MarthaSilk365', 'Martha', 'Silk'),
#  ('MarthaSilk376', 'Martha', 'Silk'),
#  ('MichelleBrooks112', 'Michelle', 'Brooks'),
#  ('MichelleBrooks135', 'Michelle', 'Brooks'),
#  ('MichelleBrooks157', 'Michelle', 'Brooks'),
#  ('MichelleBrooks209', 'Michelle', 'Brooks'),
#  ('MichelleBrooks330', 'Michelle', 'Brooks'),
#  ('MichelleBrooks341', 'Michelle', 'Brooks'),
#  ('MichelleBrooks396', 'Michelle', 'Brooks'),
#  ('NiklasSchröder7', 'Niklas', 'Schröder'),
#  ('NiklasSchröder30', 'Niklas', 'Schröder'),
#  ('NiklasSchröder52', 'Niklas', 'Schröder'),
#  ('NiklasSchröder104', 'Niklas', 'Schröder'),
#  ('NiklasSchröder225', 'Niklas', 'Schröder'),
#  ('NiklasSchröder236', 'Niklas', 'Schröder'),
#  ('NiklasSchröder291', 'Niklas', 'Schröder'),
#  ('PatrickGray39', 'Patrick', 'Gray'),
#  ('PatrickGray168', 'Patrick', 'Gray'),
#  ('PatrickGray191', 'Patrick', 'Gray'),
#  ('PatrickGray213', 'Patrick', 'Gray'),
#  ('PatrickGray265', 'Patrick', 'Gray'),
#  ('PatrickGray386', 'Patrick', 'Gray'),
#  ('PatrickGray397', 'Patrick', 'Gray'),
#  ('PhilHughes43', 'Phil', 'Hughes'),
#  ('PhilHughes54', 'Phil', 'Hughes'),
#  ('PhilHughes109', 'Phil', 'Hughes'),
#  ('PhilHughes238', 'Phil', 'Hughes'),
#  ('PhilHughes261', 'Phil', 'Hughes'),
#  ('PhilHughes283', 'Phil', 'Hughes'),
#  ('PhilHughes335', 'Phil', 'Hughes'),
#  ('PujaSrivastava23', 'Puja', 'Srivastava'),
#  ('PujaSrivastava45', 'Puja', 'Srivastava'),
#  ('PujaSrivastava97', 'Puja', 'Srivastava'),
#  ('PujaSrivastava218', 'Puja', 'Srivastava'),
#  ('PujaSrivastava229', 'Puja', 'Srivastava'),
#  ('PujaSrivastava284', 'Puja', 'Srivastava'),
#  ('RichardCunningham70', 'Richard', 'Cunningham'),
#  ('RichardCunningham93', 'Richard', 'Cunningham'),
#  ('RichardCunningham115', 'Richard', 'Cunningham'),
#  ('RichardCunningham167', 'Richard', 'Cunningham'),
#  ('RichardCunningham288', 'Richard', 'Cunningham'),
#  ('RichardCunningham299', 'Richard', 'Cunningham'),
#  ('RichardCunningham354', 'Richard', 'Cunningham'),
#  ('RobertBrown48', 'Robert', 'Brown'),
#  ('RobertBrown169', 'Robert', 'Brown'),
#  ('RobertBrown180', 'Robert', 'Brown'),
#  ('RobertBrown235', 'Robert', 'Brown'),
#  ('RobertBrown364', 'Robert', 'Brown'),
#  ('RobertBrown387', 'Robert', 'Brown'),
#  ('RobertBrown409', 'Robert', 'Brown'),
#  ('RobertoAlmeida34', 'Roberto', 'Almeida'),
#  ('RobertoAlmeida155', 'Roberto', 'Almeida'),
#  ('RobertoAlmeida166', 'Roberto', 'Almeida'),
#  ('RobertoAlmeida221', 'Roberto', 'Almeida'),
#  ('RobertoAlmeida350', 'Roberto', 'Almeida'),
#  ('RobertoAlmeida373', 'Roberto', 'Almeida'),
#  ('RobertoAlmeida395', 'Roberto', 'Almeida'),
#  ('StanisławWójcik64', 'Stanisław', 'Wójcik'),
#  ('StanisławWójcik75', 'Stanisław', 'Wójcik'),
#  ('StanisławWójcik130', 'Stanisław', 'Wójcik'),
#  ('StanisławWójcik259', 'Stanisław', 'Wójcik'),
#  ('StanisławWójcik282', 'Stanisław', 'Wójcik'),
#  ('StanisławWójcik304', 'Stanisław', 'Wójcik'),
#  ('StanisławWójcik356', 'Stanisław', 'Wójcik'),
#  ('SteveMurray20', 'Steve', 'Murray'),
#  ('SteveMurray141', 'Steve', 'Murray'),
#  ('SteveMurray152', 'Steve', 'Murray'),
#  ('SteveMurray207', 'Steve', 'Murray'),
#  ('SteveMurray336', 'Steve', 'Murray'),
#  ('SteveMurray359', 'Steve', 'Murray'),
#  ('SteveMurray381', 'Steve', 'Murray'),
#  ('TerhiHämäläinen53', 'Terhi', 'Hämäläinen'),
#  ('TerhiHämäläinen182', 'Terhi', 'Hämäläinen'),
#  ('TerhiHämäläinen205', 'Terhi', 'Hämäläinen'),
#  ('TerhiHämäläinen227', 'Terhi', 'Hämäläinen'),
#  ('TerhiHämäläinen279', 'Terhi', 'Hämäläinen'),
#  ('TerhiHämäläinen400', 'Terhi', 'Hämäläinen'),
#  ('TerhiHämäläinen411', 'Terhi', 'Hämäläinen'),
#  ('TimGoyer15', 'Tim', 'Goyer'),
#  ('TimGoyer26', 'Tim', 'Goyer'),
#  ('TimGoyer81', 'Tim', 'Goyer'),
#  ('TimGoyer210', 'Tim', 'Goyer'),
#  ('TimGoyer233', 'Tim', 'Goyer'),
#  ('TimGoyer255', 'Tim', 'Goyer'),
#  ('TimGoyer307', 'Tim', 'Goyer'),
#  ('VictorStevens17', 'Victor', 'Stevens'),
#  ('VictorStevens69', 'Victor', 'Stevens'),
#  ('VictorStevens190', 'Victor', 'Stevens'),
#  ('VictorStevens201', 'Victor', 'Stevens'),
#  ('VictorStevens256', 'Victor', 'Stevens'),
#  ('VictorStevens385', 'Victor', 'Stevens'),
#  ('VictorStevens408', 'Victor', 'Stevens'),
#  ('WyattGirard9', 'Wyatt', 'Girard'),
#  ('WyattGirard31', 'Wyatt', 'Girard'),
#  ('WyattGirard83', 'Wyatt', 'Girard'),
#  ('WyattGirard204', 'Wyatt', 'Girard'),
#  ('WyattGirard215', 'Wyatt', 'Girard'),
#  ('WyattGirard270', 'Wyatt', 'Girard'),
#  ('WyattGirard399', 'Wyatt', 'Girard')]
